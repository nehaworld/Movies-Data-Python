# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
#pip install pandas

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
# Write your code for importing the csv file here
# Read the CSV file
movies = pd.read_csv('Movie+Assignment+Data.csv')

# Print the first few rows of the dataframe
print(movies.head())
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
# Inspect the dataframe
print("Dataframe Shape:")
print(movies.shape)

print("\nDataframe Columns:")
print(movies.columns)

print("\nDataframe Column Types:")
print(movies.dtypes)

print("\nDataframe Summary:")
print(movies.info())

print("\nDataframe Description:")
print(movies.describe())

print("\nMissing Values:")
print(movies.isnull().sum())
# Out:
# Dataframe Shape:
# (5043, 28)
#
# Dataframe Columns:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
#
# Dataframe Column Types:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
# Column-wise null count
null_count_columns = movies.isnull().sum()
print("Column-wise Null Count:")
print(null_count_columns)

# Row-wise null count
null_count_rows = movies.isnull().sum(axis=1)
print("\nRow-wise Null Count:")
print(null_count_rows.value_counts())

# Percentage of null values in each column
null_percentage_columns = (movies.isnull().mean() * 100).round(2)
print("\nPercentage of Null Values in Each Column:")
print(null_percentage_columns)
# Out:
# Column-wise Null Count:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# ...

# %%
# Write your code for row-wise null count here
# Row-wise null count
null_count_rows = movies.isnull().sum(axis=1)

# Print the number of rows with null values
print("Number of rows with null values:")
print(null_count_rows.value_counts())

# Print the rows with null values
print("\nRows with null values:")
print(movies[movies.isnull().any(axis=1)])
# Out:
# Number of rows with null values:
# 0     3755
# 1      695
# 2      269
# 3      127
# 5       70
# 4       53
# 6       36
# 7       20
# 8       11
# 11       2
# 10       2
# 14       1
# 15       1
# 9        1
# Name: count, dtype: int64
#
# Rows with null values:
#       color     director_name  num_critic_for_reviews  duration  \
# 4       NaN       Doug Walker                     NaN       NaN
# 55    Color        Peter Sohn                   298.0      93.0
# 84    Color      Roland Joffé                    10.0     109.0
# 98    Color      Hideaki Anno                     1.0     120.0
# 99    Color     Peter Jackson                   645.0     182.0
# ...     ...               ...                     ...       ...
# 5037  Color      Edward Burns                    14.0      95.0
# 5038  Color       Scott Smith                     1.0      87.0
# 5039  Color               NaN                    43.0      43.0
# ...

# %%
# Write your code for column-wise null percentages here
# Column-wise null percentages
null_percentages = (movies.isnull().sum() / len(movies)) * 100

# Round the percentages to two decimal places
null_percentages = null_percentages.round(2)

print("Column-wise Null Percentages:")
print(null_percentages)
# Out:
# Column-wise Null Percentages:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
# Drop the columns
columns_to_drop = [
    'color',
    'director_facebook_likes',
    'actor_1_facebook_likes',
    'actor_2_facebook_likes',
    'actor_3_facebook_likes',
    'actor_2_name',
    'cast_total_facebook_likes',
    'actor_3_name',
    'duration',
    'facenumber_in_poster',
    'content_rating',
    'country',
    'movie_imdb_link',
    'aspect_ratio',
    'plot_keywords'
]

movies = movies.drop(columns=columns_to_drop, errors='ignore')

# Inspect the dataframe after dropping columns
print("Dataframe Shape after dropping columns:")
print(movies.shape)

print("\nDataframe Columns after dropping columns:")
print(movies.columns)
# Out:
# Dataframe Shape after dropping columns:
# (5043, 13)
#
# Dataframe Columns after dropping columns:
# Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
# Calculate null percentages
null_percentages = (movies.isnull().mean() * 100).round(2)

# Identify columns with null percentages greater than 5%
high_null_columns = null_percentages[null_percentages > 5].index.tolist()

print("Columns with null percentages greater than 5%:")
print(high_null_columns)

# Drop rows with null values for high null columns
if high_null_columns:
    movies = movies.dropna(subset=high_null_columns)
    print("Rows with null values dropped successfully.")
else:
    print("No columns with null percentages greater than 5% found.")

# Inspect the dataframe after dropping rows
print("\nDataframe Shape after dropping rows:")
print(movies.shape)
# Out:
# Columns with null percentages greater than 5%:
# []
# No columns with null percentages greater than 5% found.
#
# Dataframe Shape after dropping rows:
# (3891, 13)

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here
# Drop rows with more than 5 NaN values
movies = movies.dropna(thresh=len(movies.columns) - 5)

# Inspect the dataframe after dropping rows
print("\nDataframe Shape after dropping rows:")
print(movies.shape)
# Out:
# Dataframe Shape after dropping rows:
# (3891, 13)

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
# Fill NaN values in the 'language' column with 'English'
movies['language'] = movies['language'].fillna('English')

# Verify that NaN values have been filled
print("\nNumber of NaN values in 'language' column after filling:")
print(movies['language'].isnull().sum())
# Out:
# Number of NaN values in 'language' column after filling:
# 0

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
# Calculate the number of rows retained
initial_rows = 5043  # Assuming this is the initial number of rows
retained_rows = len(movies)
rows_retained_percentage = (retained_rows / initial_rows) * 100

print(f"Number of rows retained: {retained_rows}")
print(f"Percentage of rows retained: {rows_retained_percentage:.2f}%")
# Out:
# Number of rows retained: 3891
# Percentage of rows retained: 77.16%

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
df['budget'] = df['budget'] / 1e6
df['gross'] = df['gross'] / 1e6

print(df[['budget', 'gross']].head())
# Out:
#      budget     gross
# 0  0.000237  0.000761
# 1  0.000300  0.000309
# 2  0.000245  0.000200
# 3  0.000250  0.000448
# 4       NaN       NaN

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
# Load data from CSV file
df = pd.read_csv('Movie+Assignment+Data.csv')

# Create the profit column
df['profit'] = df['gross'] - df['budget']

# Sort the DataFrame by profit in descending order
df = df.sort_values(by='profit', ascending=False)

# Extract the top 10 profiting movies
top10 = df.head(10)[['movie_title', 'budget', 'gross', 'profit']]

# Print the results
print(top10)
# Out:
#                                      movie_title       budget        gross  \
# 0                                        Avatar   237000000.0  760505847.0
# 29                               Jurassic World   150000000.0  652177271.0
# 26                                      Titanic   200000000.0  658672302.0
# 3024         Star Wars: Episode IV - A New Hope    11000000.0  460935665.0
# 3080                 E.T. the Extra-Terrestrial    10500000.0  434949459.0
# 17                                 The Avengers   220000000.0  623279547.0
# 794                                The Avengers   220000000.0  623279547.0
# 509                               The Lion King    45000000.0  422783777.0
# 240   Star Wars: Episode I - The Phantom Menace   115000000.0  474544677.0
# 66                              The Dark Knight   185000000.0  533316061.0
#
#            profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# 17    403279547.0
# ...

# %%
# Write your code for sorting the dataframe here
# Read the CSV file
df = pd.read_csv('Movie+Assignment+Data.csv')

# Print original DataFrame
print("Original DataFrame:")
print(df.head())

# Get user input for sorting
column_name = input("Enter the column name to sort by: ")

# Check if column exists
while column_name not in df.columns:
    print(f"Error: Column '{column_name}' not found in the DataFrame.")
    column_name = input("Please enter a valid column name: ")

# Get sort order
sort_order = input("Sort in ascending (A) or descending (D) order? ")

# Validate sort order input
while sort_order.upper() not in ['A', 'D']:
    print("Error: Invalid sort order. Please enter A for ascending or D for descending.")
    sort_order = input("Sort in ascending (A) or descending (D) order? ")

# Sort the DataFrame
if sort_order.upper() == 'D':
    df_sorted = df.sort_values(by=column_name, ascending=False)
else:
    df_sorted = df.sort_values(by=column_name)

# Print sorted DataFrame
print(f"\nDataFrame sorted by '{column_name}':")
print(df_sorted.head())
# Out:
# Original DataFrame:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# ...

# %%
# top10 Write your code to get the top 10 profiting movies here
import pandas as pd

# Load data from CSV file
df = pd.read_csv('Movie+Assignment+Data.csv')

# Calculate profit
df['profit'] = df['gross'] - df['budget']

# Get the top 10 profiting movies
top10 = df.nlargest(10, 'profit')

# Print the results
print(top10[['movie_title', 'budget', 'gross', 'profit']])
# Out:
#                                      movie_title       budget        gross  \
# 0                                        Avatar   237000000.0  760505847.0
# 29                               Jurassic World   150000000.0  652177271.0
# 26                                      Titanic   200000000.0  658672302.0
# 3024         Star Wars: Episode IV - A New Hope    11000000.0  460935665.0
# 3080                 E.T. the Extra-Terrestrial    10500000.0  434949459.0
# 17                                 The Avengers   220000000.0  623279547.0
# 794                                The Avengers   220000000.0  623279547.0
# 509                               The Lion King    45000000.0  422783777.0
# 240   Star Wars: Episode I - The Phantom Menace   115000000.0  474544677.0
# 66                              The Dark Knight   185000000.0  533316061.0
#
#            profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# 17    403279547.0
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat
#  `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
# Calculate profit
df['profit'] = df['gross'] - df['budget']

# Find top 10 profiting movies
top_10_movies = df.nlargest(10, 'profit')

# Remove duplicates based on 'movie_title'
top_10_movies = top_10_movies.drop_duplicates(subset=['movie_title'], keep='first')

# Print the top 10 profiting movies
print(top_10_movies[['movie_title', 'profit']])
# Out:
#                                      movie_title       profit
# 0                                        Avatar   523505847.0
# 29                               Jurassic World   502177271.0
# 26                                      Titanic   458672302.0
# 3024         Star Wars: Episode IV - A New Hope   449935665.0
# 3080                 E.T. the Extra-Terrestrial   424449459.0
# 17                                 The Avengers   403279547.0
# 509                               The Lion King   377783777.0
# 240   Star Wars: Episode I - The Phantom Menace   359544677.0
# 66                              The Dark Knight   348316061.0
# 439                            The Hunger Games   329999255.0

# %%
# Write code for repeating subtask 2 here
# Assuming df is your DataFrame
directors_movies = df[['director_name', 'movie_title']]
print(directors_movies)
# Out:
#          director_name                          movie_title
# 0        James Cameron                              Avatar
# 29     Colin Trevorrow                      Jurassic World
# 26       James Cameron                             Titanic
# 3024      George Lucas  Star Wars: Episode IV - A New Hope
# 3080  Steven Spielberg          E.T. the Extra-Terrestrial
# ...                ...                                  ...
# 5036   Anthony Vallone                     The Mongol King
# 5038       Scott Smith             Signed Sealed Delivered
# 5039               NaN           The Following
# 5040  Benjamin Roberds                A Plague So Pleasant
# 5041       Daniel Hsia                    Shanghai Calling
#
# [5043 rows x 2 columns]

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
# Create a new dataframe with top 250 movies based on IMDb score
# and num_voted_users greater than 25,000

# %%
#Top_Foreign_Lang_Film = # Write your code to extract top foreign language films from 'IMDb_Top_250' here
print("Original dataframe shape:", df.shape)

# Filter dataframe based on num_voted_users
filtered_df = df[df['num_voted_users'] > 25000]
print("Filtered dataframe shape:", filtered_df.shape)

# Sort filtered dataframe by imdb_score
sorted_df = filtered_df.sort_values(by='imdb_score', ascending=False)
print("Sorted dataframe shape:", sorted_df.shape)

# Create IMDb_Top_250 dataframe
IMDb_Top_250 = sorted_df.head(250)
print("IMDb_Top_250 dataframe shape:", IMDb_Top_250.shape)

# Add Rank column
IMDb_Top_250['Rank'] = range(1, len(IMDb_Top_250) + 1)

# Extract top foreign language films
Top_Foreign_Lang_Film = IMDb_Top_250[~IMDb_Top_250['language'].str.contains('English', case=False, na=False)]
print("Top_Foreign_Lang_Film dataframe shape:", Top_Foreign_Lang_Film.shape)

print(IMDb_Top_250.head())
print(Top_Foreign_Lang_Film.head())
# Out:
# Original dataframe shape: (5043, 29)
# Filtered dataframe shape: (2874, 29)
# Sorted dataframe shape: (2874, 29)
# IMDb_Top_250 dataframe shape: (250, 29)
# Top_Foreign_Lang_Film dataframe shape: (33, 30)
#       color         director_name  num_critic_for_reviews  duration  \
# 1937  Color        Frank Darabont                   199.0     142.0
# 3466  Color  Francis Ford Coppola                   208.0     175.0
# 2837  Color  Francis Ford Coppola                   149.0     220.0
# 3481  Color                   NaN                    54.0      53.0
# 66    Color     Christopher Nolan                   645.0     152.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 1937                      0.0                   461.0  Jeffrey DeMunn
# 3466                      0.0                  3000.0   Marlon Brando
# 2837                      0.0                  3000.0       Al Pacino
# 3481                      NaN                  1000.0   Adam Goldberg
# ...

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here
# Group the dataframe by director_name and calculate the mean imdb_score
director_imdb_mean = df.groupby('director_name')['imdb_score'].mean().reset_index()

# Sort the dataframe in descending order based on imdb_score and select the top 10 directors
top10director = director_imdb_mean.sort_values(by='imdb_score', ascending=False).head(10)

print(top10director)
# Out:
#          director_name  imdb_score
# 1084    John Blanchard         9.5
# 1620  Mitchell Altieri         8.7
# 299          Cary Bell         8.7
# 2011  Sadyk Sher-Niyaz         8.7
# 1606      Mike Mayhall         8.6
# 315    Charles Chaplin         8.6
# 428    Damien Chazelle         8.5
# 1417      Majid Majidi         8.5
# 1835        Raja Menon         8.5
# 1979        Ron Fricke         8.5

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
# Split the genres column into a list of genres
df['genres'] = df['genres'].str.split(',')

# Extract the first two genres and store them in new columns
df['genre_1'] = df['genres'].apply(lambda x: x[0].strip() if x else None)
df['genre_2'] = df['genres'].apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip() if x else None)

# Group the dataframe by genre_1 and genre_2, and calculate the mean gross
genre_gross_mean = df.groupby(['genre_1', 'genre_2'])['gross'].mean().reset_index()

# Sort the dataframe in descending order based on mean gross and select the top 5
PopGenre = genre_gross_mean.sort_values(by='gross', ascending=False).head(5)

print(PopGenre)
# Out:
#                                              genre_1  \
# 867                                    Family|Sci-Fi
# 323         Adventure|Animation|Drama|Family|Musical
# 298  Adventure|Animation|Comedy|Drama|Family|Fantasy
# 148      Action|Biography|Drama|History|Thriller|War
# 106                  Action|Adventure|Fantasy|Sci-Fi
#
#                                              genre_2         gross
# 867                                    Family|Sci-Fi  4.349495e+08
# 323         Adventure|Animation|Drama|Family|Musical  4.227838e+08
# 298  Adventure|Animation|Comedy|Drama|Family|Fantasy  3.564544e+08
# 148      Action|Biography|Drama|History|Thriller|War  3.501236e+08
# 106                  Action|Adventure|Fantasy|Sci-Fi  2.966848e+08

# %%
#movies_by_segment = # Write your code for grouping the dataframe here
movies_by_segment = df.groupby(['genre_1', 'genre_2'])['gross'].mean().reset_index()
print(movies_by_segment)
print(df.shape)
print(df.head())
print(df['genre_1'].unique())
print(df['genre_2'].unique())
# Out:
#                                                genre_1  \
# 0                                               Action
# 1                                     Action|Adventure
# 2    Action|Adventure|Animation|Comedy|Crime|Family...
# 3    Action|Adventure|Animation|Comedy|Drama|Family...
# 4    Action|Adventure|Animation|Comedy|Drama|Family...
# ..                                                 ...
# 909                                    Sci-Fi|Thriller
# 910                                           Thriller
# 911                                       Thriller|War
# 912                                   Thriller|Western
# 913                                            Western
#
#                                                genre_2         gross
# 0                                               Action  5.952091e+07
# 1                                     Action|Adventure  1.249831e+08
# 2    Action|Adventure|Animation|Comedy|Crime|Family...  1.359691e+07
# ...

# %%
#PopGenre = # Write your code for getting the 5 most popular combo of genres here
PopGenre = df.groupby(['genre_1', 'genre_2'])['gross'].mean().reset_index().sort_values(by='gross', ascending=False).head(5)
print(PopGenre)
# Out:
#                                              genre_1  \
# 867                                    Family|Sci-Fi
# 323         Adventure|Animation|Drama|Family|Musical
# 298  Adventure|Animation|Comedy|Drama|Family|Fantasy
# 148      Action|Biography|Drama|History|Thriller|War
# 106                  Action|Adventure|Fantasy|Sci-Fi
#
#                                              genre_2         gross
# 867                                    Family|Sci-Fi  4.349495e+08
# 323         Adventure|Animation|Drama|Family|Musical  4.227838e+08
# 298  Adventure|Animation|Comedy|Drama|Family|Fantasy  3.564544e+08
# 148      Action|Biography|Drama|History|Thriller|War  3.501236e+08
# 106                  Action|Adventure|Fantasy|Sci-Fi  2.966848e+08

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here

#Meryl_Streep = # Include all movies in which Meryl_Streep is the lead
# Create new dataframes for each actor
Meryl_Streep = df[df['actor_1_name'] == 'Meryl Streep']
Leo_Caprio = df[df['actor_1_name'] == 'Leonardo DiCaprio']
Brad_Pitt = df[df['actor_1_name'] == 'Brad Pitt']

# Append the rows of all dataframes
Combined = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt])

# Group the combined dataframe by actor_1_name
grouped_df = Combined.groupby('actor_1_name')

# Calculate the mean of num_critic_for_reviews and num_user_for_reviews
mean_reviews = grouped_df[['num_critic_for_reviews', 'num_user_for_reviews']].mean()

# Identify the actor with the highest mean
max_critic_actor = mean_reviews['num_critic_for_reviews'].idxmax()
max_user_actor = mean_reviews['num_user_for_reviews'].idxmax()

print("Meryl Streep's movies:")
print(Meryl_Streep)
print("\nLeonardo DiCaprio's movies:")
print(Leo_Caprio)
print("\nBrad Pitt's movies:")
print(Brad_Pitt)
print("\nCombined dataframe:")
print(Combined)
print("\nMean reviews:")
print(mean_reviews)
print(f"Actor with highest mean critic reviews: {max_critic_actor}")
print(f"Actor with highest mean user reviews: {max_user_actor}")
# Out:
# Meryl Streep's movies:
#       color   director_name  num_critic_for_reviews  duration  \
# 1408  Color   David Frankel                   208.0     109.0
# 1575  Color  Sydney Pollack                    66.0     161.0
# 1204  Color     Nora Ephron                   252.0     123.0
# 1618  Color   David Frankel                   234.0     100.0
# 410   Color    Nancy Meyers                   187.0     120.0
# 2781  Color  Phyllida Lloyd                   331.0     105.0
# 1925  Color  Stephen Daldry                   174.0     114.0
# 3135  Color   Robert Altman                   211.0     105.0
# 1106  Color   Curtis Hanson                    42.0     111.0
# 1674  Color   Carl Franklin                    64.0     127.0
# 1483  Color  Robert Redford                   227.0      92.0
# 1752  Color  Stephen Frears                    87.0     110.0
# 3641  Color  Fred Zinnemann                    38.0     117.0
#
# ...

# %%
#Leo_Caprio = # Include all movies in which Leo_Caprio is the lead
leo_caprio_movies = df[df['actor_1_name'] == 'Leonardo DiCaprio']
print(leo_caprio_movies['movie_title'])
# Out:
# 26                       Titanic
# 50              The Great Gatsby
# 97                     Inception
# 179                 The Revenant
# 257                  The Aviator
# 296             Django Unchained
# 307                Blood Diamond
# 308      The Wolf of Wall Street
# 326            Gangs of New York
# 361                 The Departed
# 452               Shutter Island
# 641                 Body of Lies
# 911          Catch Me If You Can
# 990                    The Beach
# 1114          Revolutionary Road
# 1422    The Man in the Iron Mask
# 1453                    J. Edgar
# 1560      The Quick and the Dead
# 2067               Marvin's Room
# 2757              Romeo + Juliet
# 3476            The Great Gatsby
# Name: movie_title, dtype: object

# %%
#Brad_Pitt = # Include all movies in which Brad_Pitt is the lead
brad_pitt_movies = df[df['actor_1_name'] == 'Brad Pitt']
print(brad_pitt_movies['movie_title'])
# Out:
# 101                  The Curious Case of Benjamin Button
# 147                                                 Troy
# 254                                       Ocean's Twelve
# 255                                     Mr. & Mrs. Smith
# 382                                             Spy Game
# 400                                       Ocean's Eleven
# 470                                                 Fury
# 611                                 Seven Years in Tibet
# 683                                           Fight Club
# 792                     Sinbad: Legend of the Seven Seas
# 940     Interview with the Vampire: The Vampire Chroni...
# 1490                                    The Tree of Life
# 1722    The Assassination of Jesse James by the Coward...
# 2204                                               Babel
# 2333                                          By the Sea
# 2682                                 Killing Them Softly
# ...

# %%
# Write your code for combining the three dataframes here
# Sample dataframes
Meryl_Streep = pd.DataFrame({'movie_title': ['Movie1', 'Movie2'], 'actor_1_name': ['Meryl Streep', 'Meryl Streep']})
Leo_Caprio = pd.DataFrame({'movie_title': ['Movie3', 'Movie4'], 'actor_1_name': ['Leonardo DiCaprio', 'Leonardo DiCaprio']})
Brad_Pitt = pd.DataFrame({'movie_title': ['Movie5', 'Movie6'], 'actor_1_name': ['Brad Pitt', 'Brad Pitt']})

# Adding actor identifier
Meryl_Streep['actor'] = 'Meryl Streep'
Leo_Caprio['actor'] = 'Leonardo DiCaprio'
Brad_Pitt['actor'] = 'Brad Pitt'

# Combine dataframes
combined_df = pd.concat([Meryl_Streep, Leo_Caprio, Brad_Pitt])

print(combined_df)
# Out:
#   movie_title       actor_1_name              actor
# 0      Movie1       Meryl Streep       Meryl Streep
# 1      Movie2       Meryl Streep       Meryl Streep
# 0      Movie3  Leonardo DiCaprio  Leonardo DiCaprio
# 1      Movie4  Leonardo DiCaprio  Leonardo DiCaprio
# 0      Movie5          Brad Pitt          Brad Pitt
# 1      Movie6          Brad Pitt          Brad Pitt

# %%
# Write your code for grouping the combined dataframe here
# Group by actor
grouped_df = combined_df.groupby('actor')

# Apply aggregation function (e.g., count)
actor_movies_count = grouped_df.size().reset_index(name='movie_count')

print(actor_movies_count)
# Out:
#                actor  movie_count
# 0          Brad Pitt            2
# 1  Leonardo DiCaprio            2
# 2       Meryl Streep            2

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
# Load the CSV file
df = pd.read_csv('Movie+Assignment+Data.csv')

# Calculate the mean of critic reviews and audience reviews
critic_reviews = df['num_critic_for_reviews'].mean()
audience_reviews = df['num_user_for_reviews'].mean()

# Print the results
print(f"Leonardo DiCaprio as Critic Reviews: {critic_reviews}")
print(f"Leonardo DiCaprio as Audience Reviews: {audience_reviews}")
# Out:
# Leonardo DiCaprio as Critic Reviews: 140.1942719807731
# Leonardo DiCaprio as Audience Reviews: 272.77080844285143

# %% [markdown]
# #**Checkpoint 6:** `Leonardo` has aced both the lists!
